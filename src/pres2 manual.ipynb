# %%
# %load_ext autoreload
# %autoreload 2

# %%
import BingChatAccess
import ChatGPTAccess
import json
import os, re
from pptx import Presentation

# %%
def readFile():
    with open("lol.txt", "r", encoding="UTF-8") as f:
        ret = f.read()
    text = []
    sources = []
    toText = True
    for line in ret.splitlines():
        if line == "":
            toText = False
        if toText:
            text.append(line)
        else:
            urls = re.findall("(?:(?:https?|ftp):\/\/)[\w/\-?=%.]+\.[\w/\-&?=%]+", line)
            sources.extend(urls)
    return {"text" : "\n".join(text), "sources" : sources}
def writeFile(text):
    with open("lol.txt", "w", encoding="UTF-8") as f:
        f.write(text)

def readAndWrite(text):
    writeFile(text)
    input("Paste output of BingChat into file")
    return readFile()

# %%
chatGPT = ChatGPTAccess.ChatGPTAccess()

# %%
bingChat = BingChatAccess.BingChatAccess()

# %%
options = {"len" : 30, "adj" : "geographical", "top" : "Southeast Asia", "foc" : "", "folder" : "E:/honzi/OneDrive/IVP/prezentace", "lang" : "CZECH", "pointsMin" : 4, "pointsMax" : 6, "outlines" : 1, "subtitle" : "Jan Slíva", "saveName" : "Jihovýchodní asie"}

# %%
with open('prompts.json') as f:
    prompts = json.load(f)

# %%
first = prompts["outline"].format(**options)
print(first)
# Out:
# Create outline for exhaustive geographical presentation about Southeast Asia.  For each slide write only brief desriptive name. There has to be at least 30 slides. Format the list as json. Do not write anything before or after the json list. The structure of the json has to be
#
# {
# "slides":[
# "<name of slide 1">,
# "<name of slide 2">,
# "<name of slide 3">,
# "<name of slide 4">,
# ...
# "<name of slide N">
# ]
# }

# %%
answers = []
outlines = []
for i in range(options["outlines"]):
    answers.append(readAndWrite(first))

# %%
import re

for i in range(len(answers)):
    answers[i]["text"] = re.sub("```json", "", answers[i]["text"])
    answers[i]["text"] = re.sub("```", "", answers[i]["text"])

    try:
        topics  = json.loads(answers[i]["text"])
        topics = topics[list(topics.keys())[0]]

        outline = []
        for top in topics:
            outline.append("    - " + top)
        outline = "\n".join(outline)
    except:
        outline = answers[i]["text"]
        
    print("Option " + str(i) + ":")
    print(outline, end="\n\n")
# Out:
# Option 0:
#     - Introduction: What is Southeast Asia?
#     - Geography: Mainland and Insular Southeast Asia
#     - History: Ancient Civilizations and Colonialism
#     - Culture: Diversity and Unity
#     - Religion: Buddhism, Islam, Christianity and Others
#     - Politics: Independence and Integration
#     - Economy: Development and Challenges
#     - Society: Demography and Urbanization
#     - Environment: Natural Resources and Conservation
#     - Security: Conflicts and Cooperation
#     - Brunei Darussalam: The Abode of Peace
#     - Cambodia: The Kingdom of Wonder
#     - Indonesia: The Emerald of the Equator
#     - Laos: The Land of a Million Elephants
#     - Malaysia: Truly Asia
#     - Myanmar: The Golden Land
#     - The Philippines: The Pearl of the Orient Seas
#     - Singapore: The Lion City
#     - Thailand: The Land of Smiles
#     - Timor-Leste: The Rising Sun of Southeast Asia
#     - Vietnam: The Land of the Ascending Dragon
#     - ASEAN: The Association of Southeast Asian Nations
#     - Belt and Road Initiative: China's Influence in Southeast Asia
#     - Indo-Pacific Strategy: US Engagement in Southeast Asia
#     - Quad: Japan, India, Australia and US Partnership in Southeast Asia
#     - EU-ASEAN Dialogue: Europe's Role in Southeast Asia
#     - Mekong River Commission: Regional Cooperation on Water Resources
#     - Coral Triangle Initiative: Regional Cooperation on Marine Conservation
#     - South China Sea Dispute: Regional Conflict over Maritime Claims
#     - Conclusion: Southeast Asia in the 21st Century

# %%
index = int(input("What outline to use?"))


topics  = json.loads(answers[index]["text"])
topics = topics[list(topics.keys())[0]]


outline = []
for top in topics:
    outline.append("    - " + top)
outline = "\n".join(outline)

print(outline)
# Out:
#     - Introduction: What is Southeast Asia?
#     - Geography: Mainland and Insular Southeast Asia
#     - History: Ancient Civilizations and Colonialism
#     - Culture: Diversity and Unity
#     - Religion: Buddhism, Islam, Christianity and Others
#     - Politics: Independence and Integration
#     - Economy: Development and Challenges
#     - Society: Demography and Urbanization
#     - Environment: Natural Resources and Conservation
#     - Security: Conflicts and Cooperation
#     - Brunei Darussalam: The Abode of Peace
#     - Cambodia: The Kingdom of Wonder
#     - Indonesia: The Emerald of the Equator
#     - Laos: The Land of a Million Elephants
#     - Malaysia: Truly Asia
#     - Myanmar: The Golden Land
#     - The Philippines: The Pearl of the Orient Seas
#     - Singapore: The Lion City
#     - Thailand: The Land of Smiles
#     - Timor-Leste: The Rising Sun of Southeast Asia
#     - Vietnam: The Land of the Ascending Dragon
#     - ASEAN: The Association of Southeast Asian Nations
#     - Belt and Road Initiative: China's Influence in Southeast Asia
#     - Indo-Pacific Strategy: US Engagement in Southeast Asia
#     - Quad: Japan, India, Australia and US Partnership in Southeast Asia
#     - EU-ASEAN Dialogue: Europe's Role in Southeast Asia
#     - Mekong River Commission: Regional Cooperation on Water Resources
#     - Coral Triangle Initiative: Regional Cooperation on Marine Conservation
#     - South China Sea Dispute: Regional Conflict over Maritime Claims
#     - Conclusion: Southeast Asia in the 21st Century

# %%
with open('prompts.json') as f:
    prompts = json.load(f)

prompt = prompts["first_slide"].format(outline=outline, topOfSlide=topics[0], **options)

slides = []
slides.append(readAndWrite(prompt))
print(slides[0]["text"])
# Out:
# ## Introduction: What is Southeast Asia?
# - A geographical region of Asia situated east of the Indian subcontinent and south of China
# - Consists of two dissimilar portions:
#     - Mainland Southeast Asia: Cambodia, Laos, Myanmar, Thailand, Vietnam, and Singapore
#     - Insular Southeast Asia: Brunei, Indonesia, Malaysia, the Philippines, and Timor-Leste
# - Stretches some 4,000 miles at its greatest extent and encompasses some 5 million square miles of land and sea
# - Has a population of about 676 million people as of 2022
# - Has a rich and diverse history, culture, religion, politics, economy, society, environment, and security

# %%
for i in range(len(slides), len(topics)):
    gen = []
    for j in range(max(1, i-1), i):
        gen.append(slides[j]["text"])
    gen = "\n\n".join(gen)
    prompt = prompts["other_slide"].format(outline=outline, topOfSlide=topics[i], createdSlides=gen, **options)
    slides.append(readAndWrite(prompt))
    print(slides[i]["text"])
# Out:
# ## Politics: Independence and Integration
# - Most Southeast Asian countries gained independence from colonial powers after World War II
#     - Indonesia fought a war of independence against the Dutch until 1949
#     - Vietnam, Laos, and Cambodia were involved in the First and Second Indochina Wars against France and the US until 1975
#     - The Philippines became independent from the US in 1946, but faced communist and separatist insurgencies
#     - Myanmar, Malaysia, Singapore, and Brunei were former British colonies that became independent between 1948 and 1984
# - Southeast Asian countries have diverse political systems and ideologies
#     - Some are democracies, such as Indonesia, the Philippines, and Timor-Leste
#     - Some are authoritarian regimes, such as Vietnam, Laos, Cambodia, and Myanmar
#     - Some are constitutional monarchies, such as Thailand, Malaysia, and Brunei
#     - Some are city-states, such as Singapore
# - Southeast Asian countries have formed regional organizations to promote cooperation and integration
#     - The Association of Southeast Asian Nations (ASEAN) was established in 1967 to foster economic growth, social progress, cultural development, and regional stability
#     - ASEAN has expanded from five original members (Indonesia, Malaysia, the Philippines, Singapore, and Thailand) to ten members with the inclusion of Brunei, Vietnam, Laos, Myanmar, and Cambodia
#     - ASEAN has signed free trade agreements with China, Japan, South Korea, India, Australia, and New Zealand
#     - ASEAN has also initiated the ASEAN Community, which consists of three pillars: the ASEAN Political-Security Community, the ASEAN Economic Community, and the ASEAN Socio-Cultural Community
# - Southeast Asian countries face political challenges and opportunities in the 21st century
#     - Some challenges include ethnic and religious conflicts, human rights violations, corruption, environmental degradation, and transnational crimes
#     - Some opportunities include democratic transitions, civil society participation, regional integration, and strategic partnerships with major powers
# ## Economy: Development and Challenges
# - Southeast Asia is one of the most economically successful regions in the world, but faces many uncertainties and risks
#     - The Covid-19 pandemic has caused severe social and economic damage and disrupted poverty reduction and human development
#     - Global factors such as geopolitical instability, climate change, trade tensions, and financial volatility pose threats to growth and stability
#     - Domestic factors such as governance, inequality, corruption, and political conflict affect the quality and sustainability of development
# - Southeast Asia needs to diversify and upgrade its economic structure to escape the middle-income trap and achieve high-income status
#     - The region's growth has relied heavily on labor-intensive manufacturing, natural resources, and low-cost exports
#     - The region faces increasing competition from other emerging markets, rising labor costs, and diminishing returns to capital
#     - The region needs to invest more in innovation, technology, human capital, and infrastructure to boost productivity and competitiveness
# - Southeast Asia can leverage its strengths and opportunities to overcome its challenges and pursue new paths to prosperity
#     - The region has a large and dynamic population of over 600 million people, with a growing middle class and urbanization
#     - The region has a strategic location near major markets such as China, India, and Japan, and can benefit from regional integration through ASEAN
#     - The region has a rich and diverse culture, history, and natural environment that can attract tourism, investment, and cooperation
# ## Society: Demography and Urbanization
# - Southeast Asia is home to about 670 million people, with diverse ethnic, linguistic, religious and cultural backgrounds¹
# - The region has experienced rapid urbanization in the past decades, with the urban population increasing from 22% in 1970 to 46% in 2010²
#     - Urbanization is driven by economic growth, rural-urban migration, natural population increase, and administrative reclassification²
#     - Urbanization varies widely across countries, from 100% in Singapore to 21% in Cambodia³
# - Urbanization brings opportunities and challenges for development, sustainability, and social inclusion¹
#     - Opportunities include higher productivity, innovation, trade, and human capital development²
#     - Challenges include urban poverty, inequality, congestion, pollution, and vulnerability to disasters¹²
# - Southeast Asia needs to enhance regional cooperation and national policies to address the urban issues and harness the potential of urbanization¹²
#     - Regional cooperation can facilitate infrastructure development, trade facilitation, environmental protection, and conflict resolution²
#     - National policies can promote productive, inclusive, and sustainable urbanization through planning, governance, finance, and service delivery¹²
# ## Environment: Natural Resources and Conservation
# - Southeast Asia is rich in biodiversity, forests, and coral reefs, but faces serious threats from habitat loss, overexploitation, and climate change¹²
#     - The region holds **20% of the world's biodiversity**, 14% of the world's tropical forests, and 34% of global coral resources, including the greatest number of marine species in the world¹
#     - Southeast Asia has the **highest rate of deforestation** in the tropics, losing 13% of its forest cover between 1990 and 2010²
#     - Southeast Asia has the **highest proportion of threatened species** among tropical regions, with 35% of vascular plants, 42% of reptiles, 34% of birds, and 37% of mammals at risk of extinction²
# - Southeast Asia needs to balance economic development and environmental protection through regional cooperation and national policies¹²
#     - Regional cooperation can facilitate infrastructure development, trade facilitation, environmental protection, and conflict resolution²
#     - National policies can promote productive, inclusive, and sustainable urbanization through planning, governance, finance, and service delivery²
#     - Some examples of regional initiatives are the **Coral Triangle Initiative** for marine conservation and the **Mekong River Commission** for water resources management¹
#     - Some examples of national initiatives are the **Green Growth Strategy** in Vietnam and the **National Biodiversity Strategy and Action Plan** in Malaysia¹
# ## Security: Conflicts and Cooperation
# - Southeast Asia faces both **transnational and geopolitical challenges** that affect its security environment¹
#     - Transnational challenges include **disease epidemics**, **illicit drug trafficking**, **environmental crime**, and **climate-induced disasters**¹²
#     - Geopolitical challenges include **interstate disputes** over maritime boundaries, resources, and sovereignty, especially in the **South China Sea**²³
# - Southeast Asia also engages in various forms of **security cooperation** at the bilateral, regional, and multilateral levels¹
#     - Bilateral cooperation involves **defense dialogues**, **military exercises**, and **arms transfers** among Southeast Asian states and with external partners¹
#     - Regional cooperation involves **ASEAN-led mechanisms** such as the ASEAN Regional Forum, the ASEAN Defense Ministers' Meeting, and the East Asia Summit¹
#     - Multilateral cooperation involves **participation in global initiatives** such as the Global Security Initiative proposed by China, the Indo-Pacific Strategy led by the US, and the Quad partnership of Japan, India, Australia, and the US¹⁴
# - Southeast Asia needs to balance its **security interests** with its **economic development** and its **regional identity** in a complex and dynamic security landscape¹
# ## Brunei Darussalam: The Abode of Peace
# - A tiny but wealthy country located on the island of Borneo in Asia, with a population of about 460,000 people¹²
# - The second-richest country in Asia and the 11th richest in the world, based on GDP per capita (PPP), thanks to its huge oil and gas reserves²³
# - A former British protectorate that gained full independence in 1984 and adopted strict Islamic Sharia law in 2014¹²
# - Ruled by one of the oldest continuously ruling dynasties in the world, the Sultanate of Brunei, which once controlled large areas of northwest Borneo and the southern Philippines
# - Home to the largest stilt settlement in the world, Kampong Ayer, which houses around 30,000 people and is nicknamed the 'Venice of the East'²
# - Has an equatorial climate with high temperature, high humidity and heavy rainfall throughout the year⁴³
# ## Cambodia: The Kingdom of Wonder
# - A country in Southeast Asia, bordered by Thailand, Laos, Vietnam and the Gulf of Thailand¹
# - The official religion is Theravada Buddhism, practiced by about 95% of the population²
# - The home of the magnificent Angkor Wat, the largest religious monument in the world and a UNESCO World Heritage Site¹
# - A former French protectorate that gained independence in 1953 and suffered a brutal genocide under the Khmer Rouge regime from 1975 to 1979¹²³
# - One of the poorest countries in Asia, with a high rate of landmine casualties and amputees²³
# - A constitutional monarchy with a long-serving prime minister, Hun Sen, who has been in power since 1985¹³
# ## Indonesia: The Emerald of the Equator
# - A country in Southeast Asia, consisting of over 17,000 islands, some of which are the largest in the world¹⁴
# - The fourth most populous country in the world, with over 264 million people, and the largest Muslim-majority nation¹³
# - A former Dutch colony that declared independence in 1945, after a brief Japanese occupation during World War II¹⁴
# - A megadiverse country with rich biodiversity, home to the Komodo dragon, the world's largest lizard, and the Rafflesia arnoldii, the world's largest flower³
# - A member of the G20 group of leading economies, but also facing challenges such as poverty, inequality, corruption and environmental degradation²⁶
# - A country with a vibrant and diverse culture, influenced by various ethnic groups, religions and foreign influences¹¹
# ## Laos: The Land of a Million Elephants
# - A landlocked country in Southeast Asia, bordered by China, Vietnam, Cambodia, Thailand and Myanmar¹
# - A former French protectorate that gained independence in 1954, but suffered a civil war and US bombing during the Vietnam War²
# - One of the few remaining communist states in the world, ruled by the Lao People's Revolutionary Party since 1975³
# - A culturally diverse country with 49 officially recognized ethnic groups, most of whom practice Theravada Buddhism⁴
# - A largely rural and mountainous country, with the Mekong River running through it and forming part of its border with Thailand¹
#     - Home to Si Phan Don (Four Thousand Islands), a scenic archipelago in the Mekong River⁵
#     - Also home to endangered wildlife such as Irrawaddy dolphins, Asian elephants and tigers⁶.
# ## Malaysia: Truly Asia
# - A country of Southeast Asia, composed of two noncontiguous regions: **Peninsular Malaysia** on the Malay Peninsula and **East Malaysia** on the island of Borneo²
# - A former British colony that gained independence in 1957 and formed a federation with Singapore, Sabah and Sarawak in 1963, but Singapore seceded in 1965²
# - A federal constitutional monarchy with 13 states and three federal territories, headed by a king (Yang di-Pertuan Agong) elected from among nine hereditary sultans every five years²
# - A culturally diverse country with a multiethnic and multireligious population of over 32 million, where Malay is the official language and Islam is the official religion¹²⁴
#     - Home to various indigenous groups, such as the Orang Asli in Peninsular Malaysia and the Dayak, Kadazan-Dusun, Melanau and others in East Malaysia²
#     - Also home to large communities of Chinese, Indians, Eurasians and other minorities, who contribute to the rich diversity of languages, religions, cuisines and arts in Malaysia²
# - A developing country with a mixed economy, driven by the export of natural resources, such as petroleum, palm oil, rubber and tin, as well as manufacturing, tourism and services²³
#     - One of the founding members of the Association of Southeast Asian Nations (ASEAN) and a member of the Commonwealth of Nations²
#     - Known for its iconic landmarks, such as the Petronas Twin Towers in Kuala Lumpur, the world's tallest twin towers; the historic city of Malacca, a UNESCO World Heritage Site; and the biodiverse rainforests of Borneo²³
# ## Myanmar: The Golden Land
# - A country in Southeast Asia, bordered by Bangladesh, India, China, Laos, Thailand and the Andaman Sea and the Bay of Bengal¹²
# - The largest country by area in Mainland Southeast Asia and had a population of about 54 million in 2017²
# - A former British colony that gained independence in 1948 and experienced several military coups, the latest in 2021²
# - A culturally diverse country with over 100 ethnic groups, where Burmese is the official language and Buddhism is the official religion¹²
#     - Home to various indigenous peoples, such as the Chin, Kachin, Karen, Kayah, Mon, Rakhine and Shan¹
#     - Also home to large communities of Chinese, Indians and other minorities¹
# - A developing country with a mixed economy, based on the export of natural resources, such as natural gas, gems, jade and teak¹²
# - Known as "The Golden Land" for its thousands of golden pagodas and temples that dot the landscape³.
# ## The Philippines: The Pearl of the Orient Seas
# - An archipelago of over **7,100 islands** in Southeast Asia, between the South China Sea and the Pacific Ocean¹³
# - A former Spanish colony that was named after King Philip II of Spain and became independent in 1946 after being under US rule for 48 years¹
# - A predominantly Roman Catholic country with a diverse mix of ethnic groups, languages and cultures¹
#     - Has over 100 local languages, but Filipino (based on Tagalog) and English are the official languages¹
#     - Influenced by Malay, Chinese, Spanish, American and other Asian cultures¹
# - A developing country with a mixed economy, based on agriculture, services, manufacturing and remittances from overseas workers¹
# - Known for its natural beauty, rich biodiversity and cultural heritage²
#     - Has some of the world's best beaches, coral reefs, volcanoes and rainforests²
#     - Home to unique wildlife such as the Philippine eagle, the tarsier and the whale shark²³
#     - Famous for its festivals, cuisine, arts and crafts²
# ## Singapore: The Lion City
# - A sovereign island city-state in **Southeast Asia**, located at the southern tip of the Malay Peninsula²³
# - One of the world's most **honest** and **least corrupted** countries¹²
# - A **multicultural** and **multi-religious** nation with four official languages: English, Malay, Mandarin and Tamil²³
# - A **developed** and **high-income** economy, based on trade, finance, tourism and technology²³
#     - Has the world's **busiest port** by shipping tonnage and the world's **third highest GDP per capita**¹²
#     - A leader in innovation, education, health care and environmental sustainability¹²
# - A city of **contrasts**, where modern skyscrapers coexist with colonial buildings, green spaces and cultural heritage sites²⁴⁵
#     - Named after the mythical creature **Merlion**, half lion and half fish, which is a symbol of the city's origin and identity²⁴
#     - Home to attractions such as Marina Bay Sands, Gardens by the Bay, Sentosa Island and Universal Studios Singapore⁴⁵
# ## Thailand: The Land of Smiles
# - A country in the **center of the Southeast Asian Indochinese peninsula** with 76 provinces and four bordering countries¹²
# - The only country in Southeast Asia that was **never colonized** by European powers, formerly known as Siam until 1939¹²
# - A **constitutional monarchy** since 1932, but with frequent military coups and political instability¹²
#     - Currently ruled by King Vajiralongkorn, the world's longest-serving head of state, who was born in America and studied engineering in Switzerland¹²
# - A **Buddhist** nation with 95% of the population following Theravada Buddhism¹²
#     - Home to over 40,000 temples and the world's largest gold Buddha statue at Wat Traimit in Bangkok³
# - A **diverse** and **rich** culture, influenced by Chinese, Indian, Khmer and Malay civilizations¹²
#     - Famous for its cuisine, festivals, arts, crafts, music and dance³
#     - Known for its hospitality and friendliness, earning the nickname "The Land of Smiles"³
# - A **developing** and **export-oriented** economy, based on agriculture, industry, tourism and services¹²
#     - The second-largest economy in Southeast Asia and the eighth-largest in Asia¹²
#     - The world's largest exporter of rice and rubber and a major producer of sugar, tapioca, poultry and seafood¹²
# ## Timor-Leste: The Rising Sun of Southeast Asia
# - A country in the **eastern half of the island of Timor** in the Timor Sea between Indonesia and Australia, with two smaller islands of Atauro and Jaco and an exclave of Oecusse³⁵
# - A former Portuguese colony that declared independence in 1975, but was invaded and occupied by Indonesia until 1999, when a UN-supervised referendum led to its restoration of sovereignty in 2002²³
#     - The first new sovereign state of the 21st century and one of the youngest nations in the world³⁵
#     - A member of the United Nations, the Community of Portuguese Language Countries, the Non-Aligned Movement and the g7+ group of fragile states³
# - A **democratic republic** with a semi-presidential system, where the president is the head of state and the prime minister is the head of government²³
#     - Currently led by President Francisco Guterres and Prime Minister Taur Matan Ruak²
#     - Has a unicameral National Parliament with 65 members elected by proportional representation for five-year terms²
# - A **multilingual** and **multiethnic** society, with 15 national languages recognized by the constitution, but Portuguese and Tetum as the official languages¹³
#     - About 99.5% of the population are Christians, mostly Catholics, while the rest are Muslims, Buddhists or follow indigenous beliefs¹³
#     - Descended from the aboriginal people of Australia, but also influenced by Malay, Chinese, Indian and European cultures⁴⁵
# - A **developing** country with a low-income economy, heavily dependent on oil and gas revenues, foreign aid and remittances²⁵
#     - Has one of the lowest GDP per capita in Southeast Asia, but also one of the fastest-growing economies in the world²⁵
#     - Faces challenges such as poverty, malnutrition, unemployment, corruption, illiteracy, violence and environmental degradation²⁵
# ## Vietnam: The Land of the Ascending Dragon
# - A country in **Southeast Asia** that occupies the eastern portion of the Indochinese Peninsula and has a long coastline along the South China Sea¹²
# - A former colony of **France** that fought for its independence in the First Indochina War (1946-1954) and was divided into **North** and **South** Vietnam until reunification in 1976 after the Vietnam War (1955-1975)²³
#     - The Vietnam War was one of the most deadly conflicts in history, involving the US and its allies supporting South Vietnam against the communist North Vietnam and its allies⁴
#     - The war left millions of casualties, widespread environmental damage, and a legacy of unexploded ordnance and Agent Orange contamination⁴
# - A **socialist republic** with a single-party system led by the Communist Party of Vietnam, which has been in power since 1954¹²
#     - The country has undergone significant economic and social reforms since the late 1980s, transforming from a centrally planned economy to a market-oriented one and lifting millions of people out of poverty¹²
#     - The country is one of the fastest-growing economies in the world, with a GDP growth rate of 7% in 2019, driven by exports, manufacturing, services, and tourism¹²
# - A **multicultural** and **multilingual** nation, with 54 officially recognized ethnic groups and many languages and dialects¹²
#     - The largest ethnic group is the Kinh (Viet), who make up about 86% of the population and speak Vietnamese, the official language¹²
#     - The other ethnic groups include the Tay, Thai, Muong, Khmer, Mong, Nung, and Hoa, who live mostly in the mountainous and rural areas and have their own languages and cultures¹²
# - A country with rich **natural** and **cultural** diversity, home to 16% of the world's flora and fauna species and eight UNESCO World Heritage Sites¹³⁵
#     - Some of the natural attractions include Ha Long Bay, Phong Nha-Ke Bang National Park, Fansipan Mountain, and Mekong Delta¹³⁵
#     - Some of the cultural attractions include Hoi An Ancient Town, Hue Imperial City, My Son Sanctuary, and Thang Long Citadel¹³⁵.
# ## ASEAN: The Association of Southeast Asian Nations
# - A **political and economic union** of 10 member states in Southeast Asia, established in 1967 by the Bangkok Declaration¹
# - Aims to **accelerate economic growth, social progress, cultural development, regional peace and stability** in the region and adhere to the principles of the UN Charter¹
# - Consists of three pillars: the **ASEAN Security Community**, the **ASEAN Economic Community**, and the **ASEAN Socio-Cultural Community**, agreed in 2003²
# - Has a population of over **600 million** and a combined GDP (PPP) of around **US$10.2 trillion** as of 2022, making it one of the largest and fastest growing economies in the world³
# - Engages with other countries and organizations through a network of **alliances and dialogue partners**, such as China, Japan, India, US, EU, UN, SCO, etc.¹⁴
# - Has eight **UNESCO World Heritage Sites** and diverse **natural and cultural attractions** across its member states⁵
# ## Belt and Road Initiative: China's Influence in Southeast Asia
# - A **gigantic infrastructure, trade, and connectivity project** launched by China in 2013, spreading beyond Eurasia and Southeast Asia to other regions¹
# - Aims to **increase China's collaboration and communication** with regional nations to bolster mutual development and prosperity¹
# - Viewed by some as China's **grand strategic vision** of its historical Middle Kingdom hierarchy or as a plan to gain **geopolitical power** by making smaller and weaker countries indebted to it¹
# - Viewed by others as a **fragmented and diluted** initiative that is not a unified grand strategy or as a **positive and beneficial** initiative that advances the recipient countries' political or economic goals¹
# - Has significant impacts, pitfalls, and opportunities for Southeast Asia, a region that occupies a **central place** on the map of the BRI²³
#     - Impacts: increased **investment**, **trade**, **infrastructure**, **connectivity**, and **cooperation** between China and Southeast Asian countries²⁴
#     - Pitfalls: potential risks of **debt**, **corruption**, **environmental damage**, **political interference**, and **security tensions** arising from the BRI projects²⁴
#     - Opportunities: possible benefits of **economic growth**, **social development**, **regional integration**, **diversified partnerships**, and **strategic autonomy** for the Southeast Asian countries²⁴
# ## Indo-Pacific Strategy: US Engagement in Southeast Asia
# - A **strategic vision** of the Biden-Harris administration to more firmly anchor the US in the Indo-Pacific and strengthen the region in the process²
# - Aims to pursue an Indo-Pacific region that is **free and open, connected, prosperous, secure, and resilient**²
# - Focuses on **sustained and creative collaboration** with allies, partners, and institutions, within the region and beyond it²
# - Includes the following main elements¹:
#     - Strengthening US relations with **democracies**
#     - Promoting the **economic growth** of democracies
#     - Strengthening the **defense capabilities** of democracies
#     - Helping end **internal conflicts** in democracies
#     - Helping strengthen **democratic institutions** in all Indo-Pacific countries
#     - Reducing **external military threats** to democracies
#     - Strengthening the capabilities of the US to **defend democracies**
# - Recognizes ASEAN as the **heart of the Indo-Pacific** and seeks to deepen engagement with its member states²⁴
# - Supports a peaceful resolution of disputes, including in the **South China Sea**, and opposes any unilateral or coercive actions that undermine regional stability or international rules-based order²
# ## Quad: Japan, India, Australia and US Partnership in Southeast Asia
# - A **strategic security dialogue** between the four democracies to counter China's influence and uphold a **free and open Indo-Pacific**¹
# - Initiated in 2007 by Japanese Prime Minister Shinzo Abe, revived in 2017 by US President Donald Trump, and held its first leaders' summit in 2021 by US President Joe Biden¹
# - Launched a **vaccine partnership** to deliver 1 billion Covid-19 vaccines to countries in the Indo-Pacific region²
# - Discussed cooperation on **climate change, critical technologies, cyber space, counter-terrorism, maritime security and humanitarian assistance**²
# - Announced the **Indo-Pacific Partnership for Maritime Domain Awareness (IPMDA)** to help Pacific Islands and Southeast Asian countries track illegal fishing and other illicit activities in their waters³
# - Faced with **scepticism and caution** from ASEAN, which prefers not to choose sides and insists on ASEAN centrality in regional cooperation²⁴
#     - Some ASEAN countries, such as Vietnam and Singapore, have shown more openness to the Quad than others, such as Indonesia and Malaysia⁴
#     - The Quad has tried to address ASEAN's concerns by focusing on more practical cooperation rather than security confrontation²
# ## EU-ASEAN Dialogue: Europe's Role in Southeast Asia
# - A **strategic partnership** between the EU and ASEAN since 2020, based on shared values and interests⁶
# - A **comprehensive cooperation** in various sectors, such as trade, investment, connectivity, security, environment, climate change, human rights, education and culture⁴⁶
#     - The EU is ASEAN's **third largest trading partner** and **largest source of foreign direct investment**⁴
#     - The EU supports ASEAN's **regional integration** and **community building** through various programmes and initiatives, such as E-READI³, ARISE Plus⁴, AHA Centre⁴ and SHARE⁴
#     - The EU and ASEAN have established regular **high-level dialogues** on topics of mutual interest, such as environment and climate change¹, maritime security⁴, defence⁴ and human rights⁴
# - A **mutual support** in addressing regional and global challenges, such as the Covid-19 pandemic, the Myanmar crisis, the South China Sea dispute and the sustainable development goals⁶
#     - The EU has provided over €800 million to support ASEAN's response to Covid-19, including vaccine delivery, health system strengthening and socio-economic recovery⁶
#     - The EU has expressed its solidarity with ASEAN's efforts to resolve the situation in Myanmar and welcomed the Five-Point Consensus adopted by the ASEAN Leaders' Meeting on 24 April 2021⁶
#     - The EU has reaffirmed its support for ASEAN's role in promoting peace and stability in the South China Sea and called for the full and effective implementation of the Declaration on the Conduct of Parties in the South China Sea (DOC) and the early conclusion of an effective and substantive Code of Conduct (COC)⁶
#     - The EU has aligned its development cooperation with ASEAN's priorities under the ASEAN Comprehensive Recovery Framework (ACRF) and the ASEAN Community Vision 2025 Blueprints⁶
# ## Mekong River Commission: Regional Cooperation on Water Resources
# - An inter-governmental organisation that works with Cambodia, Laos, Thailand and Vietnam to jointly manage and develop the Mekong River and its resources¹
# - Established in 1995 with the signing of the Agreement on the Cooperation for the Sustainable Development of the Mekong River Basin¹³
# - Provides scientific analysis and advice, data and information sharing, basin monitoring and assessment, flood and drought forecasting, dialogue and partnership, and basin planning¹²
# - Supports regional cooperation on water-related issues, such as hydropower development, climate change adaptation, fisheries management, navigation, environmental protection and transboundary projects¹²³
# - Faces challenges from competing interests, upstream developments, geopolitical tensions, and institutional constraints²⁴
# ## Coral Triangle Initiative: Regional Cooperation on Marine Conservation
# - A **multilateral partnership** of six countries: Indonesia, Malaysia, Papua New Guinea, Philippines, Solomon Islands and Timor-Leste¹²³⁴
# - Established in 2009 with the signing of the **Leaders Declaration** to safeguard the region's marine and coastal resources²
# - Recognized as a **global epicenter** of marine life abundance and diversity, with over 600 coral species and 3000 fish species³⁴
# - Addresses crucial issues such as **food security, climate change and marine biodiversity** through a 10-year Regional Plan of Action (RPOA) with five goals²
#     - Strengthening the management of seascapes
#     - Promoting an ecosystem approach to fisheries management
#     - Establishing and improving effective management of marine protected areas
#     - Improving coastal community resilience to climate change
#     - Protecting threatened species
# - Works collaboratively with development partners, non-government organizations and communities to achieve better management and conservation practices²
# ## South China Sea Dispute: Regional Conflict over Maritime Claims
# - A **major shipping route** and a **rich fishing ground** with potential **natural resources**¹²
# - China claims most of the sea based on its **nine-dash line** that dates back to 1947²
#     - The line covers the **Paracel Islands** and the **Spratly Islands**, which are also claimed by other countries²
#     - The line is not recognized by international law or the 2016 ruling of the Permanent Court of Arbitration²
# - Other claimants include **Vietnam, the Philippines, Taiwan, Malaysia and Brunei**¹²
#     - They base their claims on historical ties, geographical proximity or the UN Convention on the Law of the Sea²
#     - They have built military facilities, airstrips or artificial islands on some of the disputed features²
# - The US and its allies support the freedom of navigation and oppose China's assertive actions in the sea¹²
#     - They have conducted naval patrols, military exercises and diplomatic initiatives to challenge China's claims¹²
#     - They have also provided assistance and cooperation to some of the claimants, such as the Philippines and Vietnam¹²
# - The dispute poses a risk of escalation and confrontation that could affect regional stability and global trade¹²
#     - There have been incidents of harassment, intimidation and violence between the claimants' vessels²
#     - There have been tensions over fishing rights, oil exploration and environmental protection²
#     - There have been diplomatic disputes over legal frameworks, code of conduct and dispute resolution mechanisms²
# ## Conclusion: Southeast Asia in the 21st Century
# - Southeast Asia is a **diverse and dynamic region** with a rich history and culture
# - Southeast Asia faces **challenges and opportunities** in the areas of development, environment, security and integration
#     - Development: balancing economic growth, social welfare and human rights
#     - Environment: managing natural resources, conserving biodiversity and addressing climate change
#     - Security: resolving conflicts, promoting cooperation and maintaining stability
#     - Integration: enhancing regional identity, fostering dialogue and engaging with external partners
# - Southeast Asia is a **key player** in the global arena, especially in the Indo-Pacific region
#     - Southeast Asia has strategic importance as a major shipping route and a rich fishing ground
#     - Southeast Asia has strong ties with China, the US, Japan, India, Australia and Europe
#     - Southeast Asia has a collective voice through ASEAN and other regional mechanisms
# - Southeast Asia has a **bright future** in the 21st century, as it continues to evolve and adapt to changing circumstances
#     - Southeast Asia has a large and growing population, especially of young and middle-class people
#     - Southeast Asia has a vibrant and innovative culture, with diverse expressions of art, religion and identity
#     - Southeast Asia has a resilient and flexible spirit, with a history of overcoming challenges and embracing opportunities

# %%
import deepl

with open(".DeepLtoken") as f:
    auth_key = f.read()
translator = deepl.Translator(auth_key)

# %%
import re

def formatSlide(text):
    lines = text.splitlines()
    ret = []
    if lines[0][0] != "#":
        del lines[0]
    for line in lines:
        if (line != "") and (line[0] != "["):
            line = re.sub("\*\*", "", line)
            line = re.sub(" ?\[.*?\] ?", "", line)
            line = re.sub("[⁰¹²³⁴⁵⁶⁷⁸⁹₀₁₂₃₄₅₆₇₈₉]", "", line)
            ret.append(line)
    ret = "\n".join(ret)
    return ret

def transate(text, lang="CS"):
    if text == "":
        return ""
    return translator.translate_text(text, target_lang=lang).text

# %%
import roman

num = 1
nameOfPres = options["saveName"] + " " + str(roman.toRoman(num))

while os.path.exists(os.path.join(options["folder"], nameOfPres + ".md")):
    num += 1
    nameOfPres = options["saveName"] + " " + str(roman.toRoman(num))

# %%
print(nameOfPres)
# Out:
# Jihovýchodní asie I

# %%
pres_list = list(map(lambda x: transate(formatSlide(x["text"])), slides))
pres = "\n\n".join(pres_list)

with open(os.path.join(options["folder"], nameOfPres + ".md"), "w", encoding="UTF-8") as f:
    f.write(pres)

# %%
raw_list = list(map(lambda x: x["text"], slides))
raw = "\n\n".join(raw_list)

with open(os.path.join(options["folder"], nameOfPres + " raw.md"), "w", encoding="UTF-8") as f:
    f.write(raw)

# %%
from pptx.enum.lang import MSO_LANGUAGE_ID
from pptx.util import Pt

def addSlide(power, text, language, font_size=20):
    lines = text.splitlines()
    if len(lines) == 0:
        return

    lang_id = getattr(MSO_LANGUAGE_ID, language)

    lay = power.slide_layouts[1]
    slide = power.slides.add_slide(lay)

    slide.shapes.title.text = re.sub("^## +", "", lines[0])
    slide.shapes.title.text_frame.paragraphs[0].font.language_id = lang_id

    text_frame = slide.shapes.placeholders[1].text_frame

    first = True
    for line in lines[1:]:
        if first:
            p = text_frame.paragraphs[0]
            first = False
        else:
            p = text_frame.add_paragraph()
        p.text = re.sub("^ *- +", "", line)
        p.font.language_id = lang_id
        p.font.size = Pt(font_size)
        if line[0] == "-":
            p.level = 0
        else:
            p.level = 1

    

power = Presentation("template.pptx")
power.core_properties.language = options["lang"]

lay = power.slide_layouts[0]
first = power.slides.add_slide(lay)
first.shapes.title.text = transate(options["top"])
first.placeholders[1].text= options["subtitle"]

for slide in pres_list:
    addSlide(power, slide, options["lang"])
power.save(os.path.join(options["folder"], nameOfPres + ".pptx"))

# %%
with open(os.path.join(options["folder"], nameOfPres + " sources.txt"), "w", encoding="UTF-8") as f:
    for i in range(len(slides)):
        if pres_list[i].rstrip() == "":
            continue
        f.write(pres_list[i].splitlines()[0] + "\n")
        for source in slides[i]["sources"]:
            f.write(source + "\n")
        f.write("\n")
